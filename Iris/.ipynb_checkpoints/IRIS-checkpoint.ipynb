# %%
import matplotlib.pyplot as plt

import numpy as np
import pandas as pd
import sklearn
from sklearn.datasets import make_regression as MR
from sklearn.linear_model import LinearRegression as LR, Lasso as LLR
from sklearn.model_selection import train_test_split, KFold, cross_val_score

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F 

import torchvision
from torchvision import *
from torch.nn import *
from NN import NN

from PIL import Image, ImageDraw, ImageFont
from tqdm import tqdm
 
from sklearn import datasets
from random import shuffle

# %%
iris = datasets.load_iris()

# %%
X=iris['data']
Y=iris['target']

# %%
def sampletoimage(sample):
 img =  Image.fromarray(np.zeros((252,252)).astype('uint8'))
 draw = ImageDraw.Draw(img)    
 for f,s,g in zip(font_size,sample,grid):
  font = ImageFont.truetype("./font.ttf", size=f)
  draw.text(g,str(s),font=font, fill='white')

 return [np.array(img) for _ in range(3)]

# %%
font_size=[35]*4
grid=[(50,50),(150,50),(50,150),(150,150)]

# %%
X=np.array(list(map(sampletoimage,X)))

# %%
plt.imshow(X[0,0])

# %% [markdown]
# ### Neural Network

# %%
device='cuda:0'
net = NN(model=models.resnet18(pretrained=True),
         cut=1,
         add=Sequential(Linear(512,3),Softmax(dim=1)),
         gradients=8)
net=net.to(device)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=11, shuffle=True)
X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size=0.2, random_state=1, shuffle=True)

train_data = torch.utils.data.DataLoader(list(zip(X_train,Y_train)), batch_size=32, shuffle=True, drop_last=True,num_workers=2)
validation_data = torch.utils.data.DataLoader(list(zip(X_val,Y_val)),batch_size=1,num_workers=2) 

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.01, momentum=0.9)

net.optimization(criterion,optimizer)
Train_stats, Test_stats = net.TRAIN(train_data,validation_data, 
                                    epochs=30, 
                                    batch_size=32,
                                    verbose=1,
                                    random_seed=1,
                                    device=device)

#net.save()
# Out:
# -----      TRAIN RESULTS      -----
# {'Epoch': 1.0, 'Accuracy': 0.3645833333333333, 'Loss': 1.0868095954259236}
# -----      Validation  RESULTS     -----
# {'Epoch': 1.0, 'Accuracy': 0.2916666666666667, 'Loss': 1.111176905532678}
# -----      TRAIN RESULTS      -----
# {'Epoch': 2.0, 'Accuracy': 0.6875, 'Loss': 0.9963018695513407}
# -----      Validation  RESULTS     -----
# {'Epoch': 2.0, 'Accuracy': 0.4583333333333333, 'Loss': 1.0761920263369877}
# -----      TRAIN RESULTS      -----
# {'Epoch': 3.0, 'Accuracy': 0.8125, 'Loss': 0.854728619257609}
# -----      Validation  RESULTS     -----
# {'Epoch': 3.0, 'Accuracy': 0.7083333333333334, 'Loss': 1.020521881679694}
# -----      TRAIN RESULTS      -----
# {'Epoch': 4.0, 'Accuracy': 0.9166666666666666, 'Loss': 0.7492410739262899}
# -----      Validation  RESULTS     -----
# {'Epoch': 4.0, 'Accuracy': 0.8333333333333334, 'Loss': 0.9163388659556707}
# -----      TRAIN RESULTS      -----
# {'Epoch': 5.0, 'Accuracy': 0.9375, 'Loss': 0.6772796511650085}
# -----      Validation  RESULTS     -----
# {'Epoch': 5.0, 'Accuracy': 0.9166666666666666, 'Loss': 0.8007383222381274}
# -----      TRAIN RESULTS      -----
# {'Epoch': 6.0, 'Accuracy': 0.9270833333333334, 'Loss': 0.6486406922340393}
# -----      Validation  RESULTS     -----
# {'Epoch': 6.0, 'Accuracy': 0.9583333333333334, 'Loss': 0.7037319466471672}
# -----      TRAIN RESULTS      -----
# {'Epoch': 7.0, 'Accuracy': 0.9375, 'Loss': 0.6283220847447714}
# -----      Validation  RESULTS     -----
# {'Epoch': 7.0, 'Accuracy': 0.9166666666666666, 'Loss': 0.6530623659491539}
# -----      TRAIN RESULTS      -----
# {'Epoch': 8.0, 'Accuracy': 0.96875, 'Loss': 0.6058929562568665}
# -----      Validation  RESULTS     -----
# {'Epoch': 8.0, 'Accuracy': 0.9166666666666666, 'Loss': 0.6312496289610863}
# -----      TRAIN RESULTS      -----
# {'Epoch': 9.0, 'Accuracy': 0.9791666666666666, 'Loss': 0.5970115065574646}
# -----      Validation  RESULTS     -----
# {'Epoch': 9.0, 'Accuracy': 0.9166666666666666, 'Loss': 0.6179409697651863}
# -----      TRAIN RESULTS      -----
# {'Epoch': 10.0, 'Accuracy': 0.9791666666666666, 'Loss': 0.5844322443008423}
# -----      Validation  RESULTS     -----
# {'Epoch': 10.0, 'Accuracy': 0.9583333333333334, 'Loss': 0.6095416098833084}
# -----      TRAIN RESULTS      -----
# {'Epoch': 11.0, 'Accuracy': 0.9895833333333334, 'Loss': 0.5847363869349161}
# -----      Validation  RESULTS     -----
# {'Epoch': 11.0, 'Accuracy': 0.9583333333333334, 'Loss': 0.6044444292783737}
# -----      TRAIN RESULTS      -----
# {'Epoch': 12.0, 'Accuracy': 0.9895833333333334, 'Loss': 0.579155703385671}
# -----      Validation  RESULTS     -----
# {'Epoch': 12.0, 'Accuracy': 0.9583333333333334, 'Loss': 0.6008693700035413}
# -----      TRAIN RESULTS      -----
# {'Epoch': 13.0, 'Accuracy': 0.9895833333333334, 'Loss': 0.574122428894043}
# -----      Validation  RESULTS     -----
# {'Epoch': 13.0, 'Accuracy': 0.9583333333333334, 'Loss': 0.5988700067003568}
# -----      TRAIN RESULTS      -----
# {'Epoch': 14.0, 'Accuracy': 0.9895833333333334, 'Loss': 0.572361946105957}
# -----      Validation  RESULTS     -----
# {'Epoch': 14.0, 'Accuracy': 0.9583333333333334, 'Loss': 0.5987124318877856}
# -----      TRAIN RESULTS      -----
# {'Epoch': 15.0, 'Accuracy': 0.9895833333333334, 'Loss': 0.5705357591311137}
# -----      Validation  RESULTS     -----
# {'Epoch': 15.0, 'Accuracy': 0.9583333333333334, 'Loss': 0.598798580467701}
# -----      TRAIN RESULTS      -----
# {'Epoch': 16.0, 'Accuracy': 0.9895833333333334, 'Loss': 0.5688576698303223}
# -----      Validation  RESULTS     -----
# {'Epoch': 16.0, 'Accuracy': 0.9583333333333334, 'Loss': 0.599100557466348}
# -----      TRAIN RESULTS      -----
# {'Epoch': 17.0, 'Accuracy': 0.9895833333333334, 'Loss': 0.5691775878270467}
# -----      Validation  RESULTS     -----
# {'Epoch': 17.0, 'Accuracy': 0.9583333333333334, 'Loss': 0.5991883799433708}
# -----      TRAIN RESULTS      -----
# {'Epoch': 18.0, 'Accuracy': 0.9895833333333334, 'Loss': 0.5702895323435465}
# -----      Validation  RESULTS     -----
# {'Epoch': 18.0, 'Accuracy': 0.9583333333333334, 'Loss': 0.5998282134532928}
# -----      TRAIN RESULTS      -----
# {'Epoch': 19.0, 'Accuracy': 0.9895833333333334, 'Loss': 0.5662146409352621}
# -----      Validation  RESULTS     -----
# {'Epoch': 19.0, 'Accuracy': 0.9583333333333334, 'Loss': 0.6001391857862473}
# -----      TRAIN RESULTS      -----
# {'Epoch': 20.0, 'Accuracy': 0.9895833333333334, 'Loss': 0.5656710465749105}
# -----      Validation  RESULTS     -----
# {'Epoch': 20.0, 'Accuracy': 0.9583333333333334, 'Loss': 0.5998299792408943}
# -----      TRAIN RESULTS      -----
# {'Epoch': 21.0, 'Accuracy': 0.9895833333333334, 'Loss': 0.5657049814860026}
# -----      Validation  RESULTS     -----
# {'Epoch': 21.0, 'Accuracy': 0.9583333333333334, 'Loss': 0.5995484963059425}
# -----      TRAIN RESULTS      -----
# {'Epoch': 22.0, 'Accuracy': 0.9895833333333334, 'Loss': 0.5648780266443888}
# -----      Validation  RESULTS     -----
# {'Epoch': 22.0, 'Accuracy': 0.9583333333333334, 'Loss': 0.5995499715209007}
# -----      TRAIN RESULTS      -----
# {'Epoch': 23.0, 'Accuracy': 0.9895833333333334, 'Loss': 0.5649382869402567}
# -----      Validation  RESULTS     -----
# {'Epoch': 23.0, 'Accuracy': 0.9583333333333334, 'Loss': 0.5996089105804762}
# -----      TRAIN RESULTS      -----
# {'Epoch': 24.0, 'Accuracy': 0.9895833333333334, 'Loss': 0.56439208984375}
# -----      Validation  RESULTS     -----
# {'Epoch': 24.0, 'Accuracy': 0.9583333333333334, 'Loss': 0.6000081499417623}
# -----      TRAIN RESULTS      -----
# {'Epoch': 25.0, 'Accuracy': 0.9895833333333334, 'Loss': 0.5643781224886576}
# -----      Validation  RESULTS     -----
# {'Epoch': 25.0, 'Accuracy': 0.9583333333333334, 'Loss': 0.6002791499098142}
# -----      TRAIN RESULTS      -----
# {'Epoch': 26.0, 'Accuracy': 0.9895833333333334, 'Loss': 0.5659008423487345}
# -----      Validation  RESULTS     -----
# {'Epoch': 26.0, 'Accuracy': 0.9583333333333334, 'Loss': 0.6003302931785583}
# -----      TRAIN RESULTS      -----
# {'Epoch': 27.0, 'Accuracy': 0.9895833333333334, 'Loss': 0.566477636496226}
# -----      Validation  RESULTS     -----
# {'Epoch': 27.0, 'Accuracy': 0.9583333333333334, 'Loss': 0.6002743542194366}
# -----      TRAIN RESULTS      -----
# {'Epoch': 28.0, 'Accuracy': 0.9895833333333334, 'Loss': 0.5643090605735779}
# -----      Validation  RESULTS     -----
# {'Epoch': 28.0, 'Accuracy': 0.9583333333333334, 'Loss': 0.600139282643795}
# -----      TRAIN RESULTS      -----
# {'Epoch': 29.0, 'Accuracy': 0.9895833333333334, 'Loss': 0.5636476476987203}
# -----      Validation  RESULTS     -----
# {'Epoch': 29.0, 'Accuracy': 0.9583333333333334, 'Loss': 0.6002062037587166}
# -----      TRAIN RESULTS      -----
# {'Epoch': 30.0, 'Accuracy': 0.9895833333333334, 'Loss': 0.5658742984135946}
# -----      Validation  RESULTS     -----
# {'Epoch': 30.0, 'Accuracy': 0.9583333333333334, 'Loss': 0.599249042570591}

# %% [markdown]
# ## Visualization

# %%
C=net.confusion_matrix(X_val,Y_val,heatmap=True)

# %%
net.plot('Accuracy')
net.plot('Loss')

# %% [markdown]
# ### TESTING OUR PERFORMANCE

# %%
net.load() # load the best model

# %%
net.confusion_matrix(X_test,Y_test,heatmap=True)
# Out:
# array([[ 9,  0,  0],
#        [ 0, 10,  0],
#        [ 0,  1, 10]], dtype=int64)

# %%
net.score(X_test,Y_test)
# Out:
# 0.9666666666666667
