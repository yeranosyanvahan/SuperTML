# %%
import matplotlib.pyplot as plt

import numpy as np
import pandas as pd
import sklearn
from sklearn.datasets import make_regression as MR
from sklearn.linear_model import LinearRegression as LR, Lasso as LLR
from sklearn.model_selection import train_test_split, KFold, cross_val_score

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F 

import torchvision
from torchvision import *
from torch.nn import *
from NN import NN, ClassificationReport

from PIL import Image, ImageDraw, ImageFont
from tqdm import tqdm
 
from sklearn import datasets
from random import shuffle

# %%
iris = datasets.load_iris()

# %%
X=iris['data']
Y=iris['target']

# %%
def sampletoimage(sample):
 img =  Image.fromarray(np.zeros((252,252)).astype('uint8'))
 draw = ImageDraw.Draw(img)    
 for f,s,g in zip(font_size,sample,grid):
  font = ImageFont.truetype("./font.ttf", size=f)
  draw.text(g,str(s),font=font, fill='white')

 return [np.array(img) for _ in range(3)]

# %%
font_size=[35]*4
grid=[(50,50),(150,50),(50,150),(150,150)]

# %%
X=np.array(list(map(sampletoimage,X)))

# %%
plt.imshow(X[0,0])

# %% [markdown]
# ### Neural Network

# %%
device='cuda:0'
net = NN(model=models.resnet18(pretrained=True),
         cut=1,
         add=Sequential(Linear(512,3),Softmax(dim=1)),
         gradients=8)
net=net.to(device)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=11, shuffle=True)
X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size=0.2, random_state=1, shuffle=True)

train_data = torch.utils.data.DataLoader(list(zip(X_train,Y_train)), batch_size=32, shuffle=True, drop_last=True,num_workers=2)
validation_data = torch.utils.data.DataLoader(list(zip(X_val,Y_val)),batch_size=1,num_workers=2) 

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.01, momentum=0.9)

net.optimization(criterion,optimizer)
Train_stats, Test_stats = net.TRAIN(train_data,validation_data, 
                                    epochs=30, 
                                    batch_size=32,
                                    verbose=1,
                                    random_seed=1,
                                    device=device)

#net.save()
# Out:
# -----      TRAIN RESULTS      -----
# {'Epoch': 1.0, 'Accuracy': 0.5, 'Loss': 1.0624192555745442}
# -----      Validation  RESULTS     -----
# {'Epoch': 1.0, 'Accuracy': 0.20833333333333334, 'Loss': 1.1122449338436127}
# -----      TRAIN RESULTS      -----
# {'Epoch': 2.0, 'Accuracy': 0.7083333333333334, 'Loss': 0.9755236705144247}
# -----      Validation  RESULTS     -----
# {'Epoch': 2.0, 'Accuracy': 0.7083333333333334, 'Loss': 1.0550272092223167}
# -----      TRAIN RESULTS      -----
# {'Epoch': 3.0, 'Accuracy': 0.875, 'Loss': 0.8154172301292419}
# -----      Validation  RESULTS     -----
# {'Epoch': 3.0, 'Accuracy': 0.75, 'Loss': 0.9802656322717667}
# -----      TRAIN RESULTS      -----
# {'Epoch': 4.0, 'Accuracy': 0.9375, 'Loss': 0.72837762037913}
# -----      Validation  RESULTS     -----
# {'Epoch': 4.0, 'Accuracy': 0.75, 'Loss': 0.8789345175027847}
# -----      TRAIN RESULTS      -----
# {'Epoch': 5.0, 'Accuracy': 0.9166666666666666, 'Loss': 0.6706850926081339}
# -----      Validation  RESULTS     -----
# {'Epoch': 5.0, 'Accuracy': 0.9166666666666666, 'Loss': 0.784196654955546}
# -----      TRAIN RESULTS      -----
# {'Epoch': 6.0, 'Accuracy': 0.9270833333333334, 'Loss': 0.6472994685173035}
# -----      Validation  RESULTS     -----
# {'Epoch': 6.0, 'Accuracy': 0.9166666666666666, 'Loss': 0.7002610142032305}
# -----      TRAIN RESULTS      -----
# {'Epoch': 7.0, 'Accuracy': 0.9375, 'Loss': 0.6323655645052592}
# -----      Validation  RESULTS     -----
# {'Epoch': 7.0, 'Accuracy': 0.9166666666666666, 'Loss': 0.6566197350621223}
# -----      TRAIN RESULTS      -----
# {'Epoch': 8.0, 'Accuracy': 0.9375, 'Loss': 0.6139412124951681}
# -----      Validation  RESULTS     -----
# {'Epoch': 8.0, 'Accuracy': 0.9166666666666666, 'Loss': 0.6387992824117342}
# -----      TRAIN RESULTS      -----
# {'Epoch': 9.0, 'Accuracy': 0.96875, 'Loss': 0.6015933553377787}
# -----      Validation  RESULTS     -----
# {'Epoch': 9.0, 'Accuracy': 0.9166666666666666, 'Loss': 0.6263008341193199}
# -----      TRAIN RESULTS      -----
# {'Epoch': 10.0, 'Accuracy': 0.9791666666666666, 'Loss': 0.5926392674446106}
# -----      Validation  RESULTS     -----
# {'Epoch': 10.0, 'Accuracy': 0.9166666666666666, 'Loss': 0.6175427784522375}
# -----      TRAIN RESULTS      -----
# {'Epoch': 11.0, 'Accuracy': 0.96875, 'Loss': 0.5947645902633667}
# -----      Validation  RESULTS     -----
# {'Epoch': 11.0, 'Accuracy': 0.9166666666666666, 'Loss': 0.6100259646773338}
# -----      TRAIN RESULTS      -----
# {'Epoch': 12.0, 'Accuracy': 0.9895833333333334, 'Loss': 0.5857342878977457}
# -----      Validation  RESULTS     -----
# {'Epoch': 12.0, 'Accuracy': 0.9583333333333334, 'Loss': 0.6025565266609192}
# -----      TRAIN RESULTS      -----
# {'Epoch': 13.0, 'Accuracy': 0.9791666666666666, 'Loss': 0.5801225701967875}
# -----      Validation  RESULTS     -----
# {'Epoch': 13.0, 'Accuracy': 0.9583333333333334, 'Loss': 0.6001909052332243}
# -----      TRAIN RESULTS      -----
# {'Epoch': 14.0, 'Accuracy': 0.9791666666666666, 'Loss': 0.5767395695050558}
# -----      Validation  RESULTS     -----
# {'Epoch': 14.0, 'Accuracy': 0.9583333333333334, 'Loss': 0.5996303583184878}
# -----      TRAIN RESULTS      -----
# {'Epoch': 15.0, 'Accuracy': 0.9895833333333334, 'Loss': 0.5722406903902689}
# -----      Validation  RESULTS     -----
# {'Epoch': 15.0, 'Accuracy': 0.9583333333333334, 'Loss': 0.5998763466874758}
# -----      TRAIN RESULTS      -----
# {'Epoch': 16.0, 'Accuracy': 0.9895833333333334, 'Loss': 0.5701428453127543}
# -----      Validation  RESULTS     -----
# {'Epoch': 16.0, 'Accuracy': 0.9583333333333334, 'Loss': 0.6005296359459559}
# -----      TRAIN RESULTS      -----
# {'Epoch': 17.0, 'Accuracy': 0.9895833333333334, 'Loss': 0.5718278884887695}
# -----      Validation  RESULTS     -----
# {'Epoch': 17.0, 'Accuracy': 0.9583333333333334, 'Loss': 0.600275807082653}
# -----      TRAIN RESULTS      -----
# {'Epoch': 18.0, 'Accuracy': 0.9895833333333334, 'Loss': 0.5718772610028585}
# -----      Validation  RESULTS     -----
# {'Epoch': 18.0, 'Accuracy': 0.9583333333333334, 'Loss': 0.6006595641374588}
# -----      TRAIN RESULTS      -----
# {'Epoch': 19.0, 'Accuracy': 0.9895833333333334, 'Loss': 0.5667843818664551}
# -----      Validation  RESULTS     -----
# {'Epoch': 19.0, 'Accuracy': 0.9583333333333334, 'Loss': 0.6008608291546503}
# -----      TRAIN RESULTS      -----
# {'Epoch': 20.0, 'Accuracy': 0.9895833333333334, 'Loss': 0.5661121408144633}
# -----      Validation  RESULTS     -----
# {'Epoch': 20.0, 'Accuracy': 0.9583333333333334, 'Loss': 0.6005725686748823}
# -----      TRAIN RESULTS      -----
# {'Epoch': 21.0, 'Accuracy': 0.9895833333333334, 'Loss': 0.5663874944051107}
# -----      Validation  RESULTS     -----
# {'Epoch': 21.0, 'Accuracy': 0.9583333333333334, 'Loss': 0.6003935361901919}
# -----      TRAIN RESULTS      -----
# {'Epoch': 22.0, 'Accuracy': 0.9895833333333334, 'Loss': 0.5654107133547465}
# -----      Validation  RESULTS     -----
# {'Epoch': 22.0, 'Accuracy': 0.9583333333333334, 'Loss': 0.6004244387149811}
# -----      TRAIN RESULTS      -----
# {'Epoch': 23.0, 'Accuracy': 0.9895833333333334, 'Loss': 0.5651916662851969}
# -----      Validation  RESULTS     -----
# {'Epoch': 23.0, 'Accuracy': 0.9583333333333334, 'Loss': 0.6004818007349968}
# -----      TRAIN RESULTS      -----
# {'Epoch': 24.0, 'Accuracy': 0.9895833333333334, 'Loss': 0.5647470553716024}
# -----      Validation  RESULTS     -----
# {'Epoch': 24.0, 'Accuracy': 0.9583333333333334, 'Loss': 0.6009362787008286}
# -----      TRAIN RESULTS      -----
# {'Epoch': 25.0, 'Accuracy': 0.9895833333333334, 'Loss': 0.5646924177805582}
# -----      Validation  RESULTS     -----
# {'Epoch': 25.0, 'Accuracy': 0.9583333333333334, 'Loss': 0.6011816213528315}
# -----      TRAIN RESULTS      -----
# {'Epoch': 26.0, 'Accuracy': 0.9895833333333334, 'Loss': 0.5664512117703756}
# -----      Validation  RESULTS     -----
# {'Epoch': 26.0, 'Accuracy': 0.9583333333333334, 'Loss': 0.6011273289720217}
# -----      TRAIN RESULTS      -----
# {'Epoch': 27.0, 'Accuracy': 0.9895833333333334, 'Loss': 0.566538135210673}
# -----      Validation  RESULTS     -----
# {'Epoch': 27.0, 'Accuracy': 0.9583333333333334, 'Loss': 0.6008297105630239}
# -----      TRAIN RESULTS      -----
# {'Epoch': 28.0, 'Accuracy': 0.9895833333333334, 'Loss': 0.5646077394485474}
# -----      Validation  RESULTS     -----
# {'Epoch': 28.0, 'Accuracy': 0.9583333333333334, 'Loss': 0.6003859316309293}
# -----      TRAIN RESULTS      -----
# {'Epoch': 29.0, 'Accuracy': 0.9895833333333334, 'Loss': 0.5638686418533325}
# -----      Validation  RESULTS     -----
# {'Epoch': 29.0, 'Accuracy': 0.9583333333333334, 'Loss': 0.6001452133059502}
# -----      TRAIN RESULTS      -----
# {'Epoch': 30.0, 'Accuracy': 0.9895833333333334, 'Loss': 0.5659679174423218}
# -----      Validation  RESULTS     -----
# {'Epoch': 30.0, 'Accuracy': 0.9583333333333334, 'Loss': 0.5988810583949089}

# %% [markdown]
# ## Visualization

# %%
net.plot('Accuracy')
net.plot('Loss')

# %%
report=ClassificationReport(net)
report.fit(X_val,Y_val)
report.heatmap()

# %%
report.plot_ROC()

# %%
report.mosaic_plot()

# %%
report.print_AUC()
# Out:
# Clas_0: 0.0
# Clas_1: 0.021052631578947368
# Clas_2: 0.015625

# %%
print("CROSS ENTROPY:",report.cross_entropy())
print("Accuracy:",report.accuracy())
# Out:
# CROSS ENTROPY: 0.09659098461421915
# Accuracy: 0.9583333333333334

# %% [markdown]
# ### TESTING OUR PERFORMANCE

# %%
device='cuda:0'
net = NN(model=models.resnet18(pretrained=True),
         cut=1,
         add=Sequential(Linear(512,3),Softmax(dim=1)),
         gradients=8)
net=net.to(device)
net.load() # load the static model

# %%
report=ClassificationReport(net)
report.fit(X_test,Y_test)
report.heatmap()

# %%
report.mosaic_plot()

# %%
report.accuracy()
# Out:
# 0.9666666666666667
